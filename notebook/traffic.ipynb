# %%
import pandas as pd

# %%
df = pd.read_csv("../data/traffic.csv")

# %%
df.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['track_id', ' type', ' traveled_d', ' avg_speed', ' lat', ' lon',
#        ' speed', ' lon_acc', ' lat_acc', ' time',
#        ...
#        ' lon_acc.224', ' lat_acc.224', ' time.224', ' lat.225', ' lon.225',
#        ' speed.225', ' lon_acc.225', ' lat_acc.225', ' time.225', ' lat.226'],
#       dtype='object', length=1361)>

# %%
df.shape
# Out:
# (991, 1361)

# %%
df.dropna()
# Out:
#      track_id            type   traveled_d   avg_speed        lat        lon  \
# 12         13             Car        90.68   10.201119  37.978947  23.734168
# 15         16             Car        98.04   36.765940  37.978859  23.734198
# 18         19             Car       112.88   36.283172  37.978739  23.734245
# 21         22      Motorcycle       130.43   48.910013  37.978605  23.734343
# 22         23   Heavy Vehicle       132.98   32.346837  37.978613  23.734419
# ..        ...             ...          ...         ...        ...        ...
# 986       987             Car       421.62   44.381487  37.979250  23.732085
# 987       988            Taxi       169.27   10.189972  37.975576  23.735660
# 988       989      Motorcycle       537.31   40.297876  37.975597  23.735707
# 989       990             Car       534.13   39.893649  37.975626  23.735725
# 990       991             Car       426.45   15.602009  37.979272  23.732123
#
# ...

# %%
df1 = pd.read_csv("../data/vehicle_details.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 991 entries, 0 to 990
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   track_id     991 non-null    int64
#  1    type        991 non-null    object
#  2    traveled_d  991 non-null    float64
#  3    avg_speed   991 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 31.1+ KB

# %%
df1.columns
# Out:
# Index(['track_id', ' type', ' traveled_d', ' avg_speed'], dtype='object')

# %%
df1[' type'].unique()
# Out:
# array([' Car', ' Bus', ' Medium Vehicle', ' Motorcycle', ' Heavy Vehicle',
#        ' Taxi'], dtype=object)

# %%
df1.groupby(' type').mean(' avg_speed',' traveled_d')
# Out:
#                    track_id   traveled_d   avg_speed
#  type
#  Bus             431.925926   327.758889   16.664074
#  Car             490.149780   309.218150   23.032397
#  Heavy Vehicle   244.500000   163.687000   16.112155
#  Medium Vehicle  506.809524   292.525714   18.017571
#  Motorcycle      520.529412   329.752843   30.082837
#  Taxi            489.032895   293.595855   20.037209
